# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('exp6.csv')

# %%
df.Pregnancies = df.Pregnancies.astype('float64')

# %%
sns.boxenplot(x=df.Pregnancies)
# Out:
# <Axes: xlabel='Pregnancies'>

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df.Pregnancies)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b9ecec3c10>,
#   <matplotlib.lines.Line2D at 0x2b9ececc5d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2b9ececced0>,
#   <matplotlib.lines.Line2D at 0x2b9ececd810>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2b9ecdfe250>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b9ecece0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b9ecece910>],
#  'means': []}

# %%
sns.boxplot(x=df.Pregnancies)
# Out:
# <Axes: xlabel='Pregnancies'>

# %%
plt.boxplot(df.Outcome)
plt.show()
